# %%
import matplotlib
# %matplotlib widget
import matplotlib.pyplot as plt 
from matplotlib.patches import Circle, PathPatch
import mpl_toolkits.mplot3d.art3d as art3d
import matplotlib.dates as mdates
import os
import numpy as np
import pandas as pd
from datetime import datetime as datetime
import pickle

# %%
geomcols=np.arange(8)
wellcols=np.arange(12)
CASSMGeom=pd.read_excel('/home/spri902/Collab_metadata/SigmaV_Channel_Monitoring_Rev_1.0_PetrovMod.xlsx',\
                        sheet_name='Geode',header=0,usecols=geomcols)
CASSMsrc=pd.read_excel('/home/spri902/Collab_metadata/SigmaV_Channel_Monitoring_Rev_1.0_PetrovMod.xlsx',\
                        sheet_name='CASSM_Channels',header=0,usecols=geomcols)
CASSMsrc.columns = [c.replace(' ','_') for c in CASSMsrc.columns]
WellGeom=pd.read_excel('/home/spri902/Collab_metadata/Well_Points.xlsx',header=0,usecols=wellcols)
# Bring in MEQ catalog
meq = pd.read_csv('/home/spri902/EGS_Collab/4850/MEQ/MEQcat.csv',header=0,parse_dates=[11],infer_datetime_format=True)
dates = mdates.date2num(meq['time'])
meq['datenums'] = dates
meq = meq[(meq['time'] > pd.to_datetime('2018-05-22T00')) & (meq['time'] < pd.to_datetime('2018-05-25T23'))]
meq.columns = meq.columns.str.replace(' ','')

#%%  fracture parameters
# frac_depth = 164.5 # meters
# frac_center = (2663/3.28084,347.5/3.28084,-4255/3.28084) #meters
# frac_radius = 12 #meters
# frac_angles = np.linspace(0,2*np.pi,101)
# x_c = np.cos(frac_angles)*frac_radius + frac_center[0]
# y_c = np.sin(frac_angles)*frac_radius + frac_center[1]

# c = Circle((frac_center[0],frac_center[1]),frac_radius)

# %%
PSTrayst = [CASSMsrc.iloc[6:12,5].values,CASSMsrc.iloc[6:12,6].values,CASSMsrc.iloc[6:12,7].values]
PSTrayed = [CASSMGeom.iloc[34,5],CASSMGeom.iloc[34,6],CASSMGeom.iloc[34,7]]

PSBrayst = [CASSMsrc.iloc[12:17,5].values,CASSMsrc.iloc[12:17,6].values,CASSMsrc.iloc[12:17,7].values]
PSBrayed = [CASSMGeom.iloc[29,5],CASSMGeom.iloc[29,6],CASSMGeom.iloc[29,7]]

# %%
# Plot entire test bed

fig=plt.figure(figsize=(4,4))
ax = fig.add_subplot(projection='3d')
s1=ax.scatter(WellGeom.iloc[1238:,3:9:6]/3.28084,WellGeom.iloc[1238:,4:10:6]/3.28084,WellGeom.iloc[1238:,5:11:6]/3.28084,\
            label='Monitoring Wells',marker='.',color='black',s=2)
s2=ax.scatter(CASSMGeom.iloc[12:23,5],CASSMGeom.iloc[12:23,6],CASSMGeom.iloc[12:23,7],label='OT hydro',marker='o',s=30,color='blue')
s3=ax.scatter(CASSMGeom.iloc[69:78:3,5],CASSMGeom.iloc[69:78:3,6],CASSMGeom.iloc[69:78:3,7],label='OT accels',marker='^',s=30,color='green')
s4=ax.scatter(CASSMGeom.iloc[60:69:3,5],CASSMGeom.iloc[60:69:3,6],CASSMGeom.iloc[60:69:3,7],label='OB accels',marker='^',s=30,color='green')
s5=ax.scatter(CASSMGeom.iloc[51:60:3,5],CASSMGeom.iloc[51:60:3,6],CASSMGeom.iloc[51:60:3,7],label='PST accels',marker='^',s=30,color='green')
s6=ax.scatter(CASSMsrc.iloc[0:6,5],CASSMsrc.iloc[0:6,6],CASSMsrc.iloc[0:6,7],label='OB Sources',marker='*',s=30,color='red')
s7=ax.scatter(CASSMsrc.iloc[6:12,5],CASSMsrc.iloc[6:12,6],CASSMsrc.iloc[6:12,7],label='PST Sources',marker='*',s=30,color='red')
s8=ax.scatter(CASSMsrc.iloc[12:17,5],CASSMsrc.iloc[12:17,6],CASSMsrc.iloc[12:17,7],label='PSB Sources',marker='*',s=30,color='red')
s9=ax.scatter(CASSMsrc.iloc[17,5],CASSMsrc.iloc[17,6],CASSMsrc.iloc[17,7],label='PDT Source',marker='*',s=30,color='red')
s10=ax.scatter(CASSMGeom.iloc[:12,5],CASSMGeom.iloc[:12,6],CASSMGeom.iloc[:12,7],label='PDB hydro',marker='o',s=30,color='blue')
s11=ax.scatter(CASSMGeom.iloc[24:30,5],CASSMGeom.iloc[24:30,6],CASSMGeom.iloc[24:30,7],label='PDT accels',marker='^',s=30,color='green')
s12=ax.scatter(CASSMGeom.iloc[30:36,5],CASSMGeom.iloc[30:36,6],CASSMGeom.iloc[30:36,7],label='PDB accels',marker='^',s=30,color='green')
s13=ax.scatter(CASSMGeom.iloc[36:39,5],CASSMGeom.iloc[36:39,6],CASSMGeom.iloc[36:39,7],label='PDT accels',marker='^',s=30,color='green')
s14=ax.scatter(CASSMGeom.iloc[39:42,5],CASSMGeom.iloc[39:42,6],CASSMGeom.iloc[39:42,7],label='PDB accels',marker='^',s=30,color='green')
s15=ax.scatter(CASSMGeom.iloc[42:51,5],CASSMGeom.iloc[42:51,6],CASSMGeom.iloc[42:51,7],label='PSB accels',marker='^',s=30,color='green')
s16=ax.scatter(WellGeom.iloc[:635,3:9:6]/3.28084,WellGeom.iloc[:635,4:10:6]/3.28084,WellGeom.iloc[:635,5:11:6]/3.28084,\
            label='Injector',marker='.',color='green',s=2)
s16=ax.scatter(WellGeom.iloc[635:1238,3:9:6]/3.28084,WellGeom.iloc[635:1238,4:10:6]/3.28084,WellGeom.iloc[635:1238,5:11:6]/3.28084,\
            label='Producer',marker='.',color='red',s=2)
# s17 = ax.scatter(WellGeom.iloc[500,3]/3.28084,WellGeom.iloc[500,4]/3.28084,WellGeom.iloc[500,5]/3.28084,label='Frac',marker="o",\
     # color="magenta", s=20*2**2)
# s17 = ax.scatter(WellGeom.iloc[1072,3]/3.28084,WellGeom.iloc[1072,4]/3.28084,WellGeom.iloc[1072,5]/3.28084,label='Frac',marker="o",\
     # color="magenta", s=20*2**2)
s17=ax.scatter(meq.x,meq.y,meq.z,s=5,c=meq['fracID'])
# s18=ax.scatter(meq25.x,meq25.y,meq25.z,s=5,c=meq25['date'])
# s18 = ax.add_patch(c)
loc = mdates.AutoDateLocator()
fig.colorbar(s17,ticks=loc)
# art3d.pathpatch_2d_to_3d(c, z=frac_center[2], zdir="y")

plt.gca().set_aspect('auto')
ax.set_xlabel('Easting')
ax.set_ylabel('Northing')
ax.set_zlabel('Elevation')

# ax.legend()
plt.show()

# %%
fig=plt.figure(figsize=(4,4))
plt.title('EGS Collab CASSM Source Receiver Geometry')
ax = fig.add_subplot(projection='3d')
s1=ax.scatter(WellGeom.iloc[1238:,3:9:6]/3.28084,WellGeom.iloc[1238:,4:10:6]/3.28084,WellGeom.iloc[1238:,5:11:6]/3.28084,\
            label='Monitoring Wells',marker='.',color='black',s=2)


s7=ax.scatter(CASSMsrc.iloc[6:12,5],CASSMsrc.iloc[6:12,6],CASSMsrc.iloc[6:12,7],label='PST Sources',marker='*',color='red')
s8=ax.scatter(CASSMsrc.iloc[12:17,5],CASSMsrc.iloc[12:17,6],CASSMsrc.iloc[12:17,7],label='PSB Sources',marker='*',color='red')
s10=ax.scatter(CASSMGeom.iloc[:12,5],CASSMGeom.iloc[:12,6],CASSMGeom.iloc[:12,7],label='PDB hydro',marker='o',color='blue')
s12=ax.scatter(CASSMGeom.iloc[30:36,5],CASSMGeom.iloc[30:36,6],CASSMGeom.iloc[30:36,7],label='PDB accels',marker='^',color='green')
s14=ax.scatter(CASSMGeom.iloc[39:42,5],CASSMGeom.iloc[39:42,6],CASSMGeom.iloc[39:42,7],label='PDB accels',marker='^',color='green')
s11=ax.scatter(CASSMGeom.iloc[24:30,5],CASSMGeom.iloc[24:30,6],CASSMGeom.iloc[24:30,7],label='PDT accels',marker='^',color='green')
s13=ax.scatter(CASSMGeom.iloc[36:39,5],CASSMGeom.iloc[36:39,6],CASSMGeom.iloc[36:39,7],label='PDT accels',marker='^',color='green')

s16=ax.scatter(WellGeom.iloc[:635,3:9:6]/3.28084,WellGeom.iloc[:635,4:10:6]/3.28084,WellGeom.iloc[:635,5:11:6]/3.28084,\
            label='Injector',marker='.',color='green',s=2)
s16=ax.scatter(WellGeom.iloc[635:1238,3:9:6]/3.28084,WellGeom.iloc[635:1238,4:10:6]/3.28084,WellGeom.iloc[635:1238,5:11:6]/3.28084,\
            label='Producer',marker='.',color='red',s=2)
for i in range(np.shape(PSTrayst)[1]):
    ax.plot([PSTrayst[0][i],PSTrayed[0]],[PSTrayst[1][i],PSTrayed[1]],[PSTrayst[2][i],PSTrayed[2]],color='magenta')
for i in range(np.shape(PSBrayst)[1]):
    ax.plot([PSBrayst[0][i],PSBrayed[0]],[PSBrayst[1][i],PSBrayed[1]],[PSBrayst[2][i],PSBrayed[2]],color='magenta')
# s17 = ax.scatter(WellGeom.iloc[500,3]/3.28084,WellGeom.iloc[500,4]/3.28084,WellGeom.iloc[500,5]/3.28084,label='Frac',marker="o",\
#      color="magenta", s=20*2**2)
# s17 = ax.scatter(WellGeom.iloc[1072,3]/3.28084,WellGeom.iloc[1072,4]/3.28084,WellGeom.iloc[1072,5]/3.28084,label='Frac',marker="o",\
#      color="magenta", s=20*2**2)
# s17=ax.scatter(meq.x,meq.y,meq.z,s=5,c=meq['datenums'])
# s18=ax.scatter(meq25.x,meq25.y,meq25.z,s=5,c=meq25['date'])

loc = mdates.AutoDateLocator()
# fig.colorbar(s17,ticks=loc,format=mdates.AutoDateFormatter(loc))


plt.gca().set_aspect('auto')
ax.set_xlabel('Easting')
ax.set_ylabel('Northing')
ax.set_zlabel('Elevation')

# ax.legend()
plt.show()
s18 = ax.add_patch(c)
art3d.pathpatch_2d_to_3d(c, z=frac_center[2], zdir="y")
